# %%
import pandas as pd
import random

comments = [
    "This video is amazing, loved every second of it!",
    "You are absolutely terrible and should quit",
    "Check out my channel for free subscribers!!!",
    "Great explanation, very helpful thank you",
    "I will find you and make you pay for this",
    "Subscribe to my channel click the link in bio",
    "This made my day, wholesome content",
    "You're so stupid nobody likes you",
    "FREE IPHONE GIVEAWAY CLICK HERE NOW",
    "Honestly one of the best videos on this topic",
    "Go kill yourself you worthless piece of garbage",
    "Make money from home visit my profile",
    "I learned so much from this thank you",
    "This is the dumbest thing I have ever seen",
    "Everyone in the comments is an idiot",
    "Win $1000 just by clicking my link",
    "Beautiful video really touched my heart",
    "I hate people like you so much",
    "Nice video keep up the good work",
    "You are a waste of everyone's time",
]

random.seed(42)
data = {'text': [random.choice(comments) for _ in range(50)]}
df = pd.DataFrame(data)
df.to_csv('test_comments.csv', index=False)
print(f"Generated {len(df)} rows")
df.head(10)
# Out:
# Generated 50 rows
#                                                text
# 0         Great explanation, very helpful thank you
# 1  This video is amazing, loved every second of it!
# 2               FREE IPHONE GIVEAWAY CLICK HERE NOW
# 3                 You're so stupid nobody likes you
# 4                 You're so stupid nobody likes you
# 5         I will find you and make you pay for this
# 6         Great explanation, very helpful thank you
# 7                    I hate people like you so much
# 8      Check out my channel for free subscribers!!!
# 9                  Nice video keep up the good work
